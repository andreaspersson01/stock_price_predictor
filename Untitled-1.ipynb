# %% [markdown]
# # Stock price prediction
#
# - Author: Andreas Persson
# - Email: apers@chalmers.se
# - github: https://github.com/andreaspersson01
# - linkedin: https://www.linkedin.com/in/andreas-persson-2011291a7/
#
# ## Introduction
#
# In this project, my goal is first to predict if the stock price for Investor B on the Stockholm Exchange, will move up or down. This will be done by using different technical indicators as input variables. This is a work in progress as I learn more about Time Series Anlysis using python. Enjoy! :D

# %%
# Imports
#!pip install pandas
import pandas as pd
import numpy as np

# Vizulasation
#!pip install matplotlib
import matplotlib.pyplot as plt

# Stock data
#!pip install yfinance
#!pip install exchange_calendars
import yfinance as yf
import exchange_calendars as xcals

# Technical Analysis package
#!pip install ta
#!pip install pandas_ta
import ta
import pandas_ta
#!pip install scikit-learn
#!pip install xgboost
import xgboost as xgb
from xgboost import plot_importance, plot_tree
import sklearn
from sklearn.metrics import accuracy_score, classification_report
# Out:
# /Users/andreas/Desktop/stock_price_predictor/.venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Fetch data for Investor B on the Stockholm Exchange
data = yf.download("INVE-B.ST", start="2004-01-07", end="2023-12-31")

# Get the Stockholm Stock Exchange calendar
stockholm_calendar = xcals.get_calendar("XSTO")

# Get the trading days
trading_days = stockholm_calendar.sessions_in_range("2004-01-14", "2023-12-31")

# Filter the data for trading days
data = data[data.index.isin(trading_days)]

plt.plot(data['Close'])
# Display the tail of the filtered data
display(data.tail())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-12-21  232.000000  232.250000  229.750000  231.149994  231.149994
# 2023-12-22  231.000000  232.500000  230.100006  231.949997  231.949997
# 2023-12-27  232.000000  233.100006  231.449997  232.100006  232.100006
# 2023-12-28  232.600006  232.949997  231.500000  231.949997  231.949997
# 2023-12-29  232.000000  233.699997  231.850006  233.500000  233.500000
#
#              Volume
# Date
# 2023-12-21  2213157
# 2023-12-22  2107061
# 2023-12-27  2610513
# 2023-12-28  2084982
# 2023-12-29  2445449

# %%
# Create target value
target = pd.DataFrame({'y': (data['Close'] > data['Close'].shift(1)).astype(int)})


display(data.head())
display(target.head())
# Out:
#               Open    High     Low   Close  Adj Close    Volume
# Date
# 2004-01-14  18.250  18.500  18.125  18.500  10.363458  17427360
# 2004-01-15  18.375  18.625  18.250  18.500  10.363458   6289232
# 2004-01-16  18.625  19.250  18.625  19.000  10.643550  27151184
# 2004-01-19  19.250  19.375  19.125  19.375  10.853622  20631728
# 2004-01-20  19.375  19.500  19.125  19.125  10.713573  18124620
#             y
# Date
# 2004-01-14  0
# 2004-01-15  0
# 2004-01-16  1
# 2004-01-19  1
# 2004-01-20  0

# %% [markdown]
# ## TODO Read about and understand these technical indicators
# ## Technical Indicators
# - Overlap Indicators:
#     - Moving Average
#     - Exponential Moving Average
#     - Double Exponential Moving Average
#     - Kaufman's Adaptive Moving Average
#     - Parabolic SAR
# - Momentum indicators:
#     - Average Directional Movement Index
#     - Price Oscillator - Absolute
#     - Commodity Channel Index
#     - Moving Average Convergence/Divergence
#     - Money Flow Index
#     - Momentum
#     - Relative Strength Index
# - Volume Indicators:
#     - Chaikin A/D Line (AD)
#     - Chaikin Oscillator
#     - On Balance Volume
# - Volatility Indicators
#     - True Range
#     - Average True Range

# %%
# Function to calculate DEMA
def calculate_dema(series, window):
    ema = series.ewm(span=window, adjust=False).mean()
    dema = 2 * ema - ema.ewm(span=window, adjust=False).mean()
    return dema

# %%
# Time frame definitions
time_frames = {
    '1_year': 252,
    'half_year': 126,
    'quarter': 63,
    'month': 21,
    'week': 5,
}

# Create a copy of the DataFrame
data = data.copy()

# Loop through each time frame and calculate indicators
for period_name, window in time_frames.items():
    # Calculate Simple Moving Average (SMA)
    data[f'SMA_{period_name}'] = ta.trend.sma_indicator(data['Close'], window=window)

    # Calculate Exponential Moving Average (EMA)
    data[f'EMA_{period_name}'] = ta.trend.ema_indicator(data['Close'], window=window)

    # Calculate Double Exponential Moving Average (DEMA)
    data[f'DEMA_{period_name}'] = calculate_dema(data['Close'], window)

    # Calculate Kaufman's Adaptive Moving Average (KAMA)
    data[f'KAMA_{period_name}'] = ta.momentum.kama(data['Close'], window=window, pow1=2, pow2=30)

    # Calculate Parabolic SAR
    psar_result = pandas_ta.psar(data['High'], data['Low'], data['Close'], acceleration=0.02, maximum=0.2)
    data[f'Parabolic_SAR_{period_name}'] = psar_result[['PSARl_0.02_0.2', 'PSARs_0.02_0.2']].max(axis=1)

    # Momentum
    data[f'Momentum_{period_name}'] = data['Close'] - data['Close'].shift(window)

    # Average Directional Movement Index (ADX)
    data[f'ADX_{period_name}'] = ta.trend.adx(data['High'], data['Low'], data['Close'], window=window)

    # Price Oscillator - Absolute (PO)
    data[f'PO_{period_name}'] = ta.trend.sma_indicator(data['Close'], window=int(window/2)) - ta.trend.sma_indicator(data['Close'], window=window)

    # Commodity Channel Index (CCI)
    data[f'CCI_{period_name}'] = ta.trend.cci(data['High'], data['Low'], data['Close'], window=window)

    # Moving Average Convergence/Divergence (MACD)
    macd = ta.trend.MACD(data['Close'], window_slow=window, window_fast=int(window/2), window_sign=int(window/3))
    data[f'MACD_{period_name}'] = macd.macd()

    # Money Flow Index (MFI)
    data[f'MFI_{period_name}'] = ta.volume.money_flow_index(data['High'], data['Low'], data['Close'], data['Volume'], window=window)

    # Relative Strength Index (RSI)
    data[f'RSI_{period_name}'] = ta.momentum.rsi(data['Close'], window=window)
    
    # Average True Range (ATR)
    data[f'ATR_{period_name}'] = ta.volatility.average_true_range(data['High'], data['Low'], data['Close'], window=window)

# Calculate Chaikin A/D Line (AD)
data['AD'] = ta.volume.chaikin_money_flow(data['High'], data['Low'], data['Close'], data['Volume'])

# Calculate Chaikin Oscillator (manually)
ad_3_ema = data['AD'].ewm(span=3, adjust=False).mean()
ad_10_ema = data['AD'].ewm(span=10, adjust=False).mean()
data['Chaikin_Oscillator'] = ad_3_ema - ad_10_ema

# Calculate On Balance Volume (OBV)
data['OBV'] = ta.volume.on_balance_volume(data['Close'], data['Volume'])

# True Range (TR)
data[f'TR'] = ta.volatility.average_true_range(data['High'], data['Low'], data['Close'], window=1)

print(max(data.isnull().sum()))
# Out:
# 252

# %%
# Drop 252 first rows:
data = data.iloc[252:]
target = target.iloc[252:]
# Show the DataFrame with the new indicators
print(data.isnull().sum())
# Drop specified columns
data = data.drop(columns=['Open', 'High', 'Low', 'Adj Close', 'Volume'])
display(data)
display(target)
# Out:
# Open                  0
# High                  0
# Low                   0
# Close                 0
# Adj Close             0
#                      ..
# ATR_week              0
# AD                    0
# Chaikin_Oscillator    0
# OBV                   0
# TR                    0
# Length: 75, dtype: int64
#                  Close  SMA_1_year  EMA_1_year  DEMA_1_year  KAMA_1_year  \
# Date
# 2005-01-12   21.875000   19.600446   19.757761    20.491142    22.122059
# 2005-01-13   21.687500   19.613095   19.773016    20.515733    22.117191
# 2005-01-14   21.625000   19.623512   19.787656    20.539027    22.112378
# 2005-01-17   21.812500   19.633185   19.803663    20.564974    22.109583
# 2005-01-18   21.625000   19.643105   19.818061    20.587638    22.104984
# ...                ...         ...         ...          ...          ...
# 2023-12-21  231.149994  210.058056  208.654590   218.080347   212.329459
# 2023-12-22  231.949997  210.226746  208.838743   218.372686   212.636607
# 2023-12-27  232.100006  210.390079  209.022627   218.663632   212.932896
# 2023-12-28  231.949997  210.557421  209.203871   218.948474   213.229898
# 2023-12-29  233.500000  210.722500  209.395935   219.254052   213.542751
#
#             Parabolic_SAR_1_year  Momentum_1_year  ADX_1_year  PO_1_year  \
# Date
# 2005-01-12             20.838147         3.375000    0.000000   0.327133
# 2005-01-13             20.919109         3.187500    0.000000   0.340774
# 2005-01-14             20.995212         2.625000    0.000000   0.357143
# 2005-01-17             21.066749         2.437500    0.000000   0.373760
# 2005-01-18             21.133994         2.500000    0.000000   0.385665
# ...                          ...              ...         ...        ...
# 2023-12-21            234.350006        42.829987    4.610416   2.722420
# 2023-12-22            234.350006        42.509995    4.624065   2.708095
# 2023-12-27            234.258006        41.160004    4.638219   2.675317
# 2023-12-28            234.167846        42.169998    4.652317   2.641706
# 2023-12-29            234.079489        41.600006    4.667062   2.622658
#
#             CCI_1_year  ...   PO_week    CCI_week  MACD_week   MFI_week  \
# Date                    ...
# 2005-01-12  217.750379  ...  0.125000   29.661017   0.078431  65.797470
# 2005-01-13  199.476994  ... -0.131250  -72.368421  -0.032371  54.559151
# 2005-01-14  181.570349  ... -0.231250 -118.794326  -0.070633  44.135753
# 2005-01-17  191.618351  ... -0.106250  -35.714286  -0.000940  44.666998
# 2005-01-18  174.043681  ... -0.006250  -89.743590  -0.047743  21.606393
# ...                ...  ...       ...         ...        ...        ...
# 2023-12-21  224.858408  ...  0.324998  -56.052504   0.400925  71.864108
# 2023-12-22  228.119706  ... -0.230003  -18.311459   0.396750  65.507092
# 2023-12-27  233.525061  ...  0.055000   25.193981   0.357659  83.825074
# 2023-12-28  230.622393  ...  0.035002   17.856741   0.219489  66.563865
# 2023-12-29  237.654943  ...  0.595000  122.037888   0.656677  62.569784
#
#              RSI_week  ATR_week        AD  Chaikin_Oscillator         OBV  \
# Date
# 2005-01-12  61.361889  0.309199  0.036627            0.030215   510669044
# 2005-01-13  49.017023  0.309859 -0.027544           -0.012484   500381004
# 2005-01-14  45.225935  0.297887  0.024983           -0.012103   495148444
# 2005-01-17  57.540589  0.275810  0.098672            0.012599   506830056
# 2005-01-18  44.917337  0.295648  0.134966            0.033107   496965076
# ...               ...       ...       ...                 ...         ...
# 2023-12-21  65.787038  2.625887  0.252343           -0.030339  3093565195
# 2023-12-22  70.663020  2.580708  0.241794           -0.030015  3095672256
# 2023-12-27  71.611335  2.394568  0.222358           -0.033339  3098282769
# 2023-12-28  68.830175  2.205654  0.217139           -0.033328  3096197787
# 2023-12-29  79.242443  2.134521  0.233423           -0.025113  3098643236
#
#                   TR
# Date
# 2005-01-12  0.250000
# 2005-01-13  0.312500
# 2005-01-14  0.250000
# 2005-01-17  0.187500
# 2005-01-18  0.375000
# ...              ...
# 2023-12-21  3.050003
# 2023-12-22  2.399994
# 2023-12-27  1.650009
# 2023-12-28  1.449997
# 2023-12-29  1.849991
#
# [4766 rows x 70 columns]
#             y
# Date
# 2005-01-12  0
# 2005-01-13  0
# 2005-01-14  0
# 2005-01-17  1
# 2005-01-18  0
# ...        ..
# 2023-12-21  0
# 2023-12-22  1
# 2023-12-27  1
# 2023-12-28  0
# 2023-12-29  1
#
# [4766 rows x 1 columns]

# %%
data.to_csv("data.csv")
target.to_csv("target.csv")

# %% [markdown]
# ## ML part

# %%
data = pd.read_csv("data.csv")
target = pd.read_csv("target.csv")
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)
target['Date'] = pd.to_datetime(target['Date'])
target.set_index('Date', inplace=True)
display(data)
display(target)
# Out:
#                  Close  SMA_1_year  EMA_1_year  DEMA_1_year  KAMA_1_year  \
# Date
# 2005-01-12   21.875000   19.600446   19.757761    20.491142    22.122059
# 2005-01-13   21.687500   19.613095   19.773016    20.515733    22.117191
# 2005-01-14   21.625000   19.623512   19.787656    20.539027    22.112378
# 2005-01-17   21.812500   19.633185   19.803663    20.564974    22.109583
# 2005-01-18   21.625000   19.643105   19.818061    20.587638    22.104984
# ...                ...         ...         ...          ...          ...
# 2023-12-21  231.149994  210.058056  208.654590   218.080347   212.329459
# 2023-12-22  231.949997  210.226746  208.838743   218.372686   212.636607
# 2023-12-27  232.100006  210.390079  209.022627   218.663632   212.932896
# 2023-12-28  231.949997  210.557421  209.203871   218.948474   213.229898
# 2023-12-29  233.500000  210.722500  209.395935   219.254052   213.542751
#
#             Parabolic_SAR_1_year  Momentum_1_year  ADX_1_year  PO_1_year  \
# Date
# 2005-01-12             20.838147         3.375000    0.000000   0.327133
# 2005-01-13             20.919109         3.187500    0.000000   0.340774
# 2005-01-14             20.995212         2.625000    0.000000   0.357143
# 2005-01-17             21.066749         2.437500    0.000000   0.373760
# 2005-01-18             21.133994         2.500000    0.000000   0.385665
# ...                          ...              ...         ...        ...
# 2023-12-21            234.350006        42.829987    4.610416   2.722420
# 2023-12-22            234.350006        42.509995    4.624065   2.708095
# 2023-12-27            234.258006        41.160004    4.638219   2.675317
# 2023-12-28            234.167846        42.169998    4.652317   2.641706
# 2023-12-29            234.079489        41.600006    4.667062   2.622658
#
#             CCI_1_year  ...   PO_week    CCI_week  MACD_week   MFI_week  \
# Date                    ...
# 2005-01-12  217.750379  ...  0.125000   29.661017   0.078431  65.797470
# 2005-01-13  199.476994  ... -0.131250  -72.368421  -0.032371  54.559151
# 2005-01-14  181.570349  ... -0.231250 -118.794326  -0.070633  44.135753
# 2005-01-17  191.618351  ... -0.106250  -35.714286  -0.000940  44.666998
# 2005-01-18  174.043681  ... -0.006250  -89.743590  -0.047743  21.606393
# ...                ...  ...       ...         ...        ...        ...
# 2023-12-21  224.858408  ...  0.324998  -56.052504   0.400925  71.864108
# 2023-12-22  228.119706  ... -0.230003  -18.311459   0.396750  65.507092
# 2023-12-27  233.525061  ...  0.055000   25.193981   0.357659  83.825074
# 2023-12-28  230.622393  ...  0.035002   17.856741   0.219489  66.563865
# 2023-12-29  237.654943  ...  0.595000  122.037888   0.656677  62.569784
#
#              RSI_week  ATR_week        AD  Chaikin_Oscillator         OBV  \
# Date
# 2005-01-12  61.361889  0.309199  0.036627            0.030215   510669044
# 2005-01-13  49.017023  0.309859 -0.027544           -0.012484   500381004
# 2005-01-14  45.225935  0.297887  0.024983           -0.012103   495148444
# 2005-01-17  57.540589  0.275810  0.098672            0.012599   506830056
# 2005-01-18  44.917337  0.295648  0.134966            0.033107   496965076
# ...               ...       ...       ...                 ...         ...
# 2023-12-21  65.787038  2.625887  0.252343           -0.030339  3093565195
# 2023-12-22  70.663020  2.580708  0.241794           -0.030015  3095672256
# 2023-12-27  71.611335  2.394568  0.222358           -0.033339  3098282769
# 2023-12-28  68.830175  2.205654  0.217139           -0.033328  3096197787
# 2023-12-29  79.242443  2.134521  0.233423           -0.025113  3098643236
#
#                   TR
# Date
# 2005-01-12  0.250000
# 2005-01-13  0.312500
# 2005-01-14  0.250000
# 2005-01-17  0.187500
# 2005-01-18  0.375000
# ...              ...
# 2023-12-21  3.050003
# 2023-12-22  2.399994
# 2023-12-27  1.650009
# 2023-12-28  1.449997
# 2023-12-29  1.849991
#
# [4766 rows x 70 columns]
#             y
# Date
# 2005-01-12  0
# 2005-01-13  0
# 2005-01-14  0
# 2005-01-17  1
# 2005-01-18  0
# ...        ..
# 2023-12-21  0
# 2023-12-22  1
# 2023-12-27  1
# 2023-12-28  0
# 2023-12-29  1
#
# [4766 rows x 1 columns]

# %%
from datetime import datetime
split_date = datetime.strptime('01-Jan-2019', '%d-%b-%Y')
train_data = data.loc[data.index <= split_date].copy()
test_data = data.loc[data.index > split_date].copy()
train_target = target.loc[target.index <= split_date].copy()
test_target = target.loc[target.index > split_date].copy()

# %%
_ = pd.DataFrame(test_data["Close"]) \
    .rename(columns={'Close': 'TEST SET'}) \
    .join(pd.DataFrame(train_data["Close"]).rename(columns={'Close': 'TRAINING SET'}), how='outer') \
    .plot(figsize=(15,5),  style='.')
train_data.drop(columns=["Close"])
test_data.drop(columns=["Close"])
# Out:
#             SMA_1_year  EMA_1_year  DEMA_1_year  KAMA_1_year  \
# Date
# 2019-01-02   95.645040   96.246248    98.099414    96.846317
# 2019-01-03   95.641965   96.218610    98.029706    96.828141
# 2019-01-04   95.649504   96.211743    98.001710    96.820981
# 2019-01-07   95.653671   96.208291    97.980683    96.816238
# 2019-01-08   95.655853   96.219292    97.988588    96.819652
# ...                ...         ...          ...          ...
# 2023-12-21  210.058056  208.654590   218.080347   212.329459
# 2023-12-22  210.226746  208.838743   218.372686   212.636607
# 2023-12-27  210.390079  209.022627   218.663632   212.932896
# 2023-12-28  210.557421  209.203871   218.948474   213.229898
# 2023-12-29  210.722500  209.395935   219.254052   213.542751
#
#             Parabolic_SAR_1_year  Momentum_1_year  ADX_1_year  PO_1_year  \
# Date
# 2019-01-02             97.284610        -0.650002    3.136981   2.027183
# 2019-01-03             96.708649        -0.775002    3.139256   2.059226
# 2019-01-04             96.190285         1.900002    3.136180   2.100099
# 2019-01-07             91.525002         1.050003    3.132246   2.146528
# 2019-01-08             91.617502         0.549995    3.124069   2.201687
# ...                          ...              ...         ...        ...
# 2023-12-21            234.350006        42.829987    4.610416   2.722420
# 2023-12-22            234.350006        42.509995    4.624065   2.708095
# 2023-12-27            234.258006        41.160004    4.638219   2.675317
# 2023-12-28            234.167846        42.169998    4.652317   2.641706
# 2023-12-29            234.079489        41.600006    4.667062   2.622658
#
#             CCI_1_year  MACD_1_year  ...   PO_week    CCI_week  MACD_week  \
# Date                                 ...
# 2019-01-02  -58.370280     0.595501  ...  0.027500  -76.257024  -0.386009
# 2019-01-03  -57.388817     0.558703  ... -0.122501  -44.139970  -0.485121
# 2019-01-04  -19.335247     0.543092  ...  0.549999  136.947055   0.467325
# 2019-01-07    0.642005     0.531114  ...  1.332500  115.600515   0.716797
# 2019-01-08   32.030358     0.533665  ...  1.717500  116.953575   1.221280
# ...                ...          ...  ...       ...         ...        ...
# 2023-12-21  224.858408     5.088828  ...  0.324998  -56.052504   0.400925
# 2023-12-22  228.119706     5.191392  ... -0.230003  -18.311459   0.396750
# 2023-12-27  233.525061     5.292074  ...  0.055000   25.193981   0.357659
# 2023-12-28  230.622393     5.388551  ...  0.035002   17.856741   0.219489
# 2023-12-29  237.654943     5.494244  ...  0.595000  122.037888   0.656677
#
#              MFI_week   RSI_week  ATR_week        AD  Chaikin_Oscillator  \
# Date
# 2019-01-02  18.085438  39.424677  2.126528 -0.015780           -0.040232
# 2019-01-03  33.483227  34.917906  1.901222 -0.091562           -0.060319
# 2019-01-04  56.435992  59.181584  2.125978 -0.152760           -0.082525
# 2019-01-07  78.988096  62.070910  1.895782 -0.107757           -0.069788
# 2019-01-08  79.075565  72.514052  1.961626 -0.058921           -0.042694
# ...               ...        ...       ...       ...                 ...
# 2023-12-21  71.864108  65.787038  2.625887  0.252343           -0.030339
# 2023-12-22  65.507092  70.663020  2.580708  0.241794           -0.030015
# 2023-12-27  83.825074  71.611335  2.394568  0.222358           -0.033339
# 2023-12-28  66.563865  68.830175  2.205654  0.217139           -0.033328
# 2023-12-29  62.569784  79.242443  2.134521  0.233423           -0.025113
#
#                    OBV        TR
# Date
# 2019-01-02  2903713908  2.375000
# 2019-01-03  2900361460  1.000000
# 2019-01-04  2904428440  3.025002
# 2019-01-07  2907732248  0.974998
# 2019-01-08  2912563880  2.224998
# ...                ...       ...
# 2023-12-21  3093565195  3.050003
# 2023-12-22  3095672256  2.399994
# 2023-12-27  3098282769  1.650009
# 2023-12-28  3096197787  1.449997
# 2023-12-29  3098643236  1.849991
#
# [1256 rows x 69 columns]

# %%
model = xgb.XGBClassifier()
model.fit(train_data, train_target)

#Making predictions on the test set
predictions = model.predict(test_data)

#Calculating accuracy
accuracy = accuracy_score(test_target, predictions)

print("Accuracy:", accuracy)
print("\nClassification Report:")
print(classification_report(test_target, predictions, target_names=["Down","Up"]))
# Out:
# Accuracy: 0.8431528662420382
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Down       0.84      0.84      0.84       609
#           Up       0.85      0.84      0.85       647
#
#     accuracy                           0.84      1256
#    macro avg       0.84      0.84      0.84      1256
# weighted avg       0.84      0.84      0.84      1256

# %%
plt.figure(figsize=(20,20))
plot_importance(model)
plt.rcParams["figure.figsize"] = (20,20)

# %% [markdown]
# ## CROSS VALIDATION
#
# I've learned that to truely test the performance of a model forecasting Time Series Data, it is important to do something called Cross Validation. (https://medium.com/@poudelsushmita878/cross-validation-in-time-series-forecasting-db2bc7601875)
#
# To explain briefly what I am doing in the code below:

# %%
from sklearn.model_selection import TimeSeriesSplit
X = data[['SMA_1_year', 'EMA_1_year', 'DEMA_1_year', 'KAMA_1_year',
       'Parabolic_SAR_1_year', 'Momentum_1_year', 'ADX_1_year', 'PO_1_year',
       'CCI_1_year', 'MACD_1_year', 'MFI_1_year', 'RSI_1_year', 'ATR_1_year',
       'SMA_half_year', 'EMA_half_year', 'DEMA_half_year', 'KAMA_half_year',
       'Parabolic_SAR_half_year', 'Momentum_half_year', 'ADX_half_year',
       'PO_half_year', 'CCI_half_year', 'MACD_half_year', 'MFI_half_year',
       'RSI_half_year', 'ATR_half_year', 'SMA_quarter', 'EMA_quarter',
       'DEMA_quarter', 'KAMA_quarter', 'Parabolic_SAR_quarter',
       'Momentum_quarter', 'ADX_quarter', 'PO_quarter', 'CCI_quarter',
       'MACD_quarter', 'MFI_quarter', 'RSI_quarter', 'ATR_quarter',
       'SMA_month', 'EMA_month', 'DEMA_month', 'KAMA_month',
       'Parabolic_SAR_month', 'Momentum_month', 'ADX_month', 'PO_month',
       'CCI_month', 'MACD_month', 'MFI_month', 'RSI_month', 'ATR_month',
       'SMA_week', 'EMA_week', 'DEMA_week', 'KAMA_week', 'Parabolic_SAR_week',
       'Momentum_week', 'ADX_week', 'PO_week', 'CCI_week', 'MACD_week',
       'MFI_week', 'RSI_week', 'ATR_week', 'AD', 'Chaikin_Oscillator', 'OBV',
       'TR']]
y = target[['y']]
close = data[['Close']]
tscv = TimeSeriesSplit()
print(tscv)
avg = []
for i, (train_index, test_index) in enumerate(tscv.split(X)):
       
       X_train, X_test = X.iloc[train_index, :], X.iloc[test_index,:]
       y_train, y_test = y.iloc[train_index], y.iloc[test_index]
       close_train, close_test = close.iloc[train_index], close.iloc[test_index]

       _ = pd.DataFrame(close_test["Close"]) \
       .rename(columns={'Close': 'TEST SET'}) \
       .join(pd.DataFrame(close_train["Close"]).rename(columns={'Close': 'TRAINING SET'}), how='outer') \
       .plot(figsize=(15,5),  style='.')
       
       model = xgb.XGBClassifier()
       model.fit(X_train, y_train)

       #Making predictions on the test set
       predictions = model.predict(X_test)

       #Calculating accuracy
       accuracy = accuracy_score(y_test, predictions)
       avg.append(accuracy)
       print(f"Fold {i}: accuracy={accuracy}")

print(np.mean(avg))
# Out:
# TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None)
# Fold 0: accuracy=0.8148614609571788
# Fold 1: accuracy=0.8639798488664987
# Fold 2: accuracy=0.8664987405541562
# Fold 3: accuracy=0.8463476070528967
# Fold 4: accuracy=0.8526448362720404
# 0.8488664987405542
